# %% [markdown]
# <a href="https://colab.research.google.com/github/amscally-dsci/Data-Science-Cohort-20/blob/main/Project-3/Project%203/Project_3_SQLChinook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project SQL - Chinook

# %% [markdown]
# ## Chinook data set
#
# See the lecture on SQLite3 using the Chinook data set to set up the software, database, and tables, as well as for the links to ancillary information about the data set.

# %%
# Imports for Sqlite setup
import sqlite3 as db
import pandas as pd
from google.colab import output

# %%
# Backup way to load sqlite3 from RC Slack chat
#  %%bash
# curl -s -O https://ddc-datascience.s3.amazonaws.com/apt/sqlite3_3.37.2-2ubuntu0.5_amd64.deb
# dpkg -i ./sqlite3_3.37.2-2ubuntu0.5_amd64.deb
# rm ./sqlite3_3.37.2-2ubuntu0.5_amd64.deb

# %%
# Install the sqlite package for Ubuntu
# %%capture install_output
# %%bash
apt-get update
apt-get install -y sqlite3
pip install sqlite-web

# %%
# Sqlite "how to" manual command
# !sqlite3 --help
# Out:
# Usage: sqlite3 [OPTIONS] FILENAME [SQL]
# FILENAME is the name of an SQLite database. A new database is created
# if the file does not previously exist.
# OPTIONS include:
#    -A ARGS...           run ".archive ARGS" and exit
#    -append              append the database to the end of the file
#    -ascii               set output mode to 'ascii'
#    -bail                stop after hitting an error
#    -batch               force batch I/O
#    -box                 set output mode to 'box'
#    -column              set output mode to 'column'
#    -cmd COMMAND         run "COMMAND" before reading stdin
#    -csv                 set output mode to 'csv'
#    -deserialize         open the database using sqlite3_deserialize()
#    -echo                print commands before execution
#    -init FILENAME       read/process named file
#    -[no]header          turn headers on or off
#    -help                show this message
#    -html                set output mode to HTML
# ...

# %%
# Sqlite command for version identification
# !sqlite3 --version
# Out:
# 3.37.2 2022-01-06 13:25:41 872ba256cbf61d9290b571c0e6d82a20c224ca3ad82971edc46b29818d5dalt1

# %%
# Download the Chinook sqlite database
# %%bash
[ -f chinook.zip ] ||
  curl -s -O https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
unzip -l chinook.zip
# Out:
# Archive:  chinook.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#    884736  2015-11-29 10:53   chinook.db
# ---------                     -------
#    884736                     1 file

# %%
# !rm -f chinook.db

# %%
# !unzip -u chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
# !ls -la
# Out:
# total 1180
# drwxr-xr-x 1 root root   4096 May  7 19:08 .
# drwxr-xr-x 1 root root   4096 May  7 18:37 ..
# -rw-r--r-- 1 root root 884736 Nov 29  2015 chinook.db
# -rw-r--r-- 1 root root 305596 May  7 19:08 chinook.zip
# drwxr-xr-x 4 root root   4096 Apr 16 13:28 .config
# drwxr-xr-x 1 root root   4096 Apr 16 13:28 sample_data

# %% [markdown]
# ## Come up with questions about your data
# Have a look at the Entity-Relation ( ER ) diagram to help come up with questions.
#
# * What sort of information is in this dataset?
# * How many records are there?
# * How many different countries (states, counties, cities, etc) have records in this data set?
#
#
# If you are stuck, here are some ideas for questions:
# - https://github.com/LucasMcL/15-sql_queries_02-chinook/blob/master/README.md
# - [Using the R language]( https://rpubs.com/enext777/636199 )
# - [Search Google]( https://www.google.com/search?q=chinook+database+questions )

# %% [markdown]
# ## Use SQL queries to pull specific information
#
# Do NOT pull all the data and then filter using DataFrame methods etc. Make sure and use AT LEAST 13 of the 15 SQL options listed below. (You may have to get creative and come up with more questions to ask/answer.)

# %% [markdown]
# ### Basic Queries

# %% [markdown]
# #### SELECT (with * and with column names)

# %%
query = '''
  SELECT
    count(1)
  FROM
    employees
;
'''
print(query)
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  df = pd.read_sql_query( query , db_con)
df
# Out:
#   SELECT
#     count(1)
#   FROM
#     employees
# ;
#    count(1)
# 0         8

# %%
query = '''
  select *
  from employees
  limit 10
'''
print(query)
# Out:
#   select *
#   from employees
#   limit 10

# %%
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  df = pd.read_sql_query( query , db_con)
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
query = '''
  select *
  from employees
;
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  df = pd.read_sql_query( query , db_con)
df
# Out:
#   select *
#   from employees
# ;
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# ...

# %%
# df is now synonymous with employees from the 2f chinook.end lecture
df.shape
# Out:
# (8, 15)

# %%
query= '''
  SELECT Count(1)
  From customers
;
'''
print(query)

#Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#   SELECT Count(1)
#   From customers
# ;
#    Count(1)
# 0        59

# %%
query= '''
  SELECT *
  From customers
;
'''
print(query)

#Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#   SELECT *
#   From customers
# ;
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# ...

# %%
customers.shape
# Out:
# (59, 13)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerId    59 non-null     int64
#  1   FirstName     59 non-null     object
#  2   LastName      59 non-null     object
#  3   Company       10 non-null     object
#  4   Address       59 non-null     object
#  5   City          59 non-null     object
#  6   State         30 non-null     object
#  7   Country       59 non-null     object
#  8   PostalCode    55 non-null     object
#  9   Phone         58 non-null     object
#  10  Fax           12 non-null     object
#  11  Email         59 non-null     object
#  12  SupportRepId  59 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.1+ KB

# %% [markdown]
# #### WHERE

# %%
query= '''
  SELECT *
  FROM customers
  WHERE Country= 'Brazil'
'''
print(query)
# Out:
#   SELECT *
#   FROM customers
#   WHERE Country= 'Brazil'

# %%
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#    CustomerId  FirstName   LastName  \
# 0           1       Luís  Gonçalves
# 1          10    Eduardo    Martins
# 2          11  Alexandre      Rocha
# 3          12    Roberto    Almeida
# 4          13   Fernanda      Ramos
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                  Woodstock Discos
# 2                              Banco do Brasil S.A.
# 3                                            Riotur
# 4                                              None
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1        Rua Dr. Falcão Filho, 155            São Paulo    SP  Brazil
# 2               Av. Paulista, 2022            São Paulo    SP  Brazil
# 3                 Praça Pio X, 119       Rio de Janeiro    RJ  Brazil
# 4                     Qe 7 Bloco G             Brasília    DF  Brazil
#
# ...

# %%
query= '''
  SELECT COUNT(1), COUNT(Country)
  FROM customers
  -- WHERE Country= 'Brazil'
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT COUNT(1), COUNT(Country)
#   FROM customers
#   -- WHERE Country= 'Brazil'
#    COUNT(1)  COUNT(Country)
# 0        59              59

# %%
query= '''
  SELECT Country, COUNT(Country)
  FROM customers
  GROUP BY Country
  -- ORDER BY Country
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT Country, COUNT(Country)
#   FROM customers
#   GROUP BY Country
#   -- ORDER BY Country
#            Country  COUNT(Country)
# 0        Argentina               1
# 1        Australia               1
# 2          Austria               1
# 3          Belgium               1
# 4           Brazil               5
# 5           Canada               8
# 6            Chile               1
# 7   Czech Republic               2
# 8          Denmark               1
# 9          Finland               1
# 10          France               5
# 11         Germany               4
# 12         Hungary               1
# 13           India               2
# 14         Ireland               1
# 15           Italy               1
# 16     Netherlands               1
# 17          Norway               1
# 18          Poland               1
# 19        Portugal               2
# 20           Spain               1
# 21          Sweden               1
# 22             USA              13
# ...

# %%
query = '''
  select *
  from customers

'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   select *
#   from customers
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# ...

# %%
query='''
  SELECT
    Country
  FROM
    customers
;
'''
print(query)
# Out:
#   SELECT
#     Country
#   FROM
#     customers
# ;

# %%
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5   Czech Republic
# 6          Austria
# 7          Belgium
# 8          Denmark
# 9           Brazil
# 10          Brazil
# 11          Brazil
# 12          Brazil
# 13          Canada
# 14          Canada
# 15             USA
# 16             USA
# 17             USA
# 18             USA
# 19             USA
# 20             USA
# 21             USA
# 22             USA
# 23             USA
# 24             USA
# 25             USA
# 26             USA
# 27             USA
# 28          Canada
# 29          Canada
# 30          Canada
# 31          Canada
# 32          Canada
# 33        Portugal
# 34        Portugal
# 35         Germany
# 36         Germany
# 37         Germany
# 38          France
# 39          France
# 40          France
# 41          France
# 42          France
# 43         Finland
# 44         Hungary
# 45         Ireland
# ...

# %%
query='''
  SELECT COUNT
    (DISTINCT Country)
  FROM
    customers
;
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#   SELECT COUNT
#     (DISTINCT Country)
#   FROM
#     customers
# ;
#    COUNT\n    (DISTINCT Country)
# 0                             24

# %%
query='''
  SELECT DISTINCT
    Country
  FROM
    customers
  ORDER BY Country
;
'''
print(query)
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#   SELECT DISTINCT
#     Country
#   FROM
#     customers
#   ORDER BY Country
# ;
#            Country
# 0        Argentina
# 1        Australia
# 2          Austria
# 3          Belgium
# 4           Brazil
# 5           Canada
# 6            Chile
# 7   Czech Republic
# 8          Denmark
# 9          Finland
# 10          France
# 11         Germany
# 12         Hungary
# 13           India
# 14         Ireland
# 15           Italy
# 16     Netherlands
# 17          Norway
# 18          Poland
# 19        Portugal
# 20           Spain
# 21          Sweden
# 22             USA
# 23  United Kingdom

# %%
# Trying GROUP BY  to output list of 24 countries accompanied by their counts
query='''
  SELECT
    Country, COUNT(Country) AS [Counts]
  FROM
    Customers
  GROUP BY
    Country
;
  '''

print(query)
# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  customers = pd.read_sql_query( query , db_con)
customers
# Out:
#   SELECT
#     Country, COUNT(Country) AS [Counts]
#   FROM
#     Customers
#   GROUP BY
#     Country
# ;
#            Country  Counts
# 0        Argentina       1
# 1        Australia       1
# 2          Austria       1
# 3          Belgium       1
# 4           Brazil       5
# 5           Canada       8
# 6            Chile       1
# 7   Czech Republic       2
# 8          Denmark       1
# 9          Finland       1
# 10          France       5
# 11         Germany       4
# 12         Hungary       1
# 13           India       2
# 14         Ireland       1
# 15           Italy       1
# 16     Netherlands       1
# 17          Norway       1
# 18          Poland       1
# 19        Portugal       2
# 20           Spain       1
# 21          Sweden       1
# 22             USA      13
# 23  United Kingdom       3

# %% [markdown]
# #### AND

# %% [markdown]
# #### OR

# %% [markdown]
# #### LIKE (with % or _ wildcard)

# %%
query = '''
  select Name
  from genres
  WHERE Name like '% % %'
  -- limit 10
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   select Name
#   from genres
#   WHERE Name like '% % %'
#   -- limit 10
#                  Name
# 0  Alternative & Punk
# 1       Rock And Roll
# 2    Sci Fi & Fantasy

# %%
SELECT * FROM Customers
WHERE CustomerName LIKE 'a%' OR CustomerName LIKE 'b%';

# %% [markdown]
# #### BETWEEN

# %% [markdown]
# #### LIMIT

# %% [markdown]
# ### Sorting and Grouping

# %% [markdown]
# #### ORDER BY

# %% [markdown]
# #### DISTINCT

# %% [markdown]
# #### GROUP BY

# %% [markdown]
# ### Aggregates

# %% [markdown]
# #### MAX

# %%
# What's the longest time for a track?
query= '''
  SELECT MAX(Milliseconds)
  FROM tracks
  -- Limit 10
;
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT MAX(Milliseconds)
#   FROM tracks
#   -- Limit 10
# ;
#    MAX(Milliseconds)
# 0            5286953

# %% [markdown]
# #### MIN

# %%
# What's the longest time for a track?
query= '''
  SELECT MIN(Milliseconds)
  FROM tracks
;
'''
print(query)

# Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT MIN(Milliseconds)
#   FROM tracks
# ;
#    MIN(Milliseconds)
# 0               1071

# %% [markdown]
# #### SUM

# %% [markdown]
# #### AVG

# %% [markdown]
# #### COUNT

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT Count(1)
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT Count(1)
#   From tracks
#   ;
#    Count(1)
# 0      3503

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT *
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT *
#   From tracks
#   ;
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
# ...

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT *
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT *
#   From tracks
#   ;
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
# ...

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT COUNT(*)
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT COUNT(*)
#   From tracks
#   ;
#    COUNT(*)
# 0      3503

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT COUNT(AlbumId)
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT COUNT(AlbumId)
#   From tracks
#   ;
#    COUNT(AlbumId)
# 0            3503

# %%
# How many unique albums are in the Tracks table?
query='''
  SELECT COUNT(DISTINCT AlbumId)
  From tracks
  ;
  '''
print(query)

  # Connect to a sqlite database, load a result set into a data frame, and close the connection
with db.connect("chinook.db") as db_con:
  display(pd.read_sql_query( query , db_con))
# Out:
#   SELECT COUNT(DISTINCT AlbumId)
#   From tracks
#   ;
#    COUNT(DISTINCT AlbumId)
# 0                      347

# %% [markdown]
# ## Make some plots
#
# Make some cool plots to go with your data. Write SQL queries to get ONLY the information you need for each plot. (Don't pull ALL the data and then just plot a few columns.)

# %% [markdown]
# ## EXTRA CREDIT:
# * Use a CTE
# * Use a query that joins two or more tables.
# * Make a model to see if you can predict something
# * Come up with something else cool to do with your data
